# %%
#let's load the one sheet I want from this excel file
import pandas as pd

file_path = r"C:\Users\Ferryadmin\Projects\data_science_projects\Electricity_Renewables_Project\data\interim\Aterio US Data Centers Dashboard Copy.xlsx"

sample_df = pd.read_excel(file_path, sheet_name="Data Sample")

print(sample_df.head())
print(sample_df.shape)
# Out:
#                  ATERIO_DATA_CENTER_UID  \
# 0  14c3ec08-1803-4368-ac7a-fbd879e635eb
# 1  c5fe22bd-0670-427c-ae03-5674b8e007ef
# 2  302036dd-074a-45de-92fb-15bc3540a4c7
# 3  28ab55b6-0148-4b98-87ad-c0b4d8dd2a05
# 4  83b54f12-8ad5-4318-8fbc-0d87e46a07a7
#
#                DATA_CENTER_BUILDING_NAME  \
# 0        Southfield Data Center NW (DC2)
# 1       MIWI1 Wells Building Data Center
# 2                  CHIL1 MTC Data Center
# 3           ORNY1 Orangeburg Data Center
# 4  Chester County Data Center Building 1
#
#           ATERIO_DATA_CENTER_CAMPUS_UID    DATA_CENTER_CAMPUS_NAME  \
# 0  15471167-b182-4a84-9204-3befe56d5657  Southfield, 123NET Campus
# 1                                   NaN                        NaN
# 2                                   NaN                        NaN
# 3                                   NaN                        NaN
# 4  0d0cee86-6c51-4401-aa69-92d99874a84a  Philadelphia, 1547 Campus
#
# ...

# %%
#save it as its own csv file to work with
sample_df.to_csv(
    r"C:\Users\Ferryadmin\Projects\data_science_projects\Electricity_Renewables_Project\data\interim\aterio_data_sample.csv",
    index=False
)

# %%
#now check columns
print(sample_df.columns.tolist())
print(sample_df.head())
# Out:
# ['ATERIO_DATA_CENTER_UID', 'DATA_CENTER_BUILDING_NAME', 'ATERIO_DATA_CENTER_CAMPUS_UID', 'DATA_CENTER_CAMPUS_NAME', 'DATA_CENTER_STAGE', 'FLG_AI_FACILITY', 'FLG_BTM_ONSITE_POWER_GENERATION', 'TOT_PROJECT_COST', 'ATERIO_PROVIDER_UID', 'PROVIDER_NAME', 'PROVIDER_URL', 'PROVIDER_PUBLIC_PRIVATE', 'PROVIDER_TICKER_NAME', 'PROVIDER_BLOOMBERG_TICKER_NAME', 'STOCK_EXCHANGE_PROVIDER_NAME', 'PROVIDER_BACKED_BY', 'CONSTRUCTION_EQUIPMENT_PROVIDER_COMPANIES', 'PROJECT_FINANCING_COMPANIES', 'END_USER_COMPANIES', 'FULL_ADDRESS', 'ZIP_CODE', 'COUNTY_FIPS_CODE', 'COUNTY_NAME', 'CITY_NAME', 'PLACE_FIPS_CODE', 'STATE_CODE', 'STATE_NAME', 'COUNTRY_CODE', 'COUNTRY_NAME', 'LOCATION_LATITUDE', 'LOCATION_LONGITUDE', 'SITE_ACREAGE', 'TOT_FACILITY_SPACE_SQFT', 'TOT_DATACENTER_SPACE_SQFT', 'PROV_PUB_TOT_POWER_CAPACITY_MW', 'ATERIO_EST_TOT_POWER_CAPACITY_MW', 'ATERIO_EST_TOT_POWER_CAPACITY_MW_LOWER', 'ATERIO_EST_TOT_POWER_CAPACITY_MW_UPPER', 'SELECTED_POWER_CAPACITY_MW', 'AVG_MARKET_POWER_COST', 'YEARLY_PUE', '
# ...
